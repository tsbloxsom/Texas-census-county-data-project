# %%
import pandas as pd

# %%
df = pd.read_csv("5. County Stats.csv")

# %%
df.head()
# Out:
#             County  Total Population  Total Families  Total Households  \
# 0  Anderson County           58458.0         12158.0           17218.0
# 1   Andrews County           14786.0          3976.0            5259.0
# 2  Angelina County           86771.0         22429.0           31090.0
# 3   Aransas County           23158.0          6536.0            9795.0
# 4    Archer County            9054.0          2597.0            3538.0
#
#    Population in Families  Population in Households  \
# 0                 37417.0                   44241.0
# 1                 12922.0                   14704.0
# 2                 71618.0                   83818.0
# 3                 18281.0                   22699.0
# 4                  7786.0                    8998.0
#
#    Family: Under Eightteen years  House: Under Eightteen years  \
# 0                        11297.0                       11471.0
# 1                         4263.0                        4312.0
# ...

# %%
def cut_county_name(s):
    return s[:-7]

df["County"] = df["County"].map(cut_county_name)

# %%
pop_df = df[["County", "Total Population"]].copy()

# %%
pop_df.head()
# Out:
#      County  Total Population
# 0  Anderson           58458.0
# 1   Andrews           14786.0
# 2  Angelina           86771.0
# 3   Aransas           23158.0
# 4    Archer            9054.0

# %%
pop_df.to_csv("County Pop Data.csv")
