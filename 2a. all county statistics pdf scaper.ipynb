# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
import re 
import pandas as pd
from pathlib import Path

# %%
def pdf_to_text(filename):

    #filename = "Anderson_2010_SF1_Profile.pdf"
    #open allows you to read the file.
    pdfFileObj = open(filename,'rb')
    #The pdfReader variable is a readable object that will be parsed.
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    #Discerning the number of pages will allow us to parse through all the pages.
    num_pages = pdfReader.numPages
    count = 0
    text = ""
    #The while loop will read each page.
    while count < num_pages:
        pageObj = pdfReader.getPage(count)
        count +=1
        text += pageObj.extractText()
    #This if statement exists to check if the above library returned words. 
    #It's done because PyPDF2 cannot read scanned files.
    if text != "":
        text = text
    #If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text.
    else:
        text = textract.process(fileurl, method='tesseract', language='eng')

    #Now we have a text variable that contains all the text derived from our PDF file. 
    #Type print(text) to see what it contains. It likely contains a lot of spaces, possibly junk such as '\n,' etc.
    
    return text

# %%
def subset_text_doc(text):
    
    #spliting up text file and finding relevant sections
    splits = text.split("===================================================================================================================================================")
    pop_sum = splits[3]
    pop_sum_table_split = pop_sum.split(" |")
    
    new_table_list = []
    for s in pop_sum_table_split:
        s = s.replace('|---------------------------------------------------------------------------------|', '')
        new_table_list.append(s)

    # Separating odd and even index elements 
    left_tables = [] 
    right_tables = [] 
    for i in range(0, len(new_table_list)): 
        if i % 2: 
            right_tables.append(new_table_list[i]) 
        else : 
            left_tables.append(new_table_list[i])

    return left_tables, splits

# %%
def get_clean_summary_table(left_tables, splits):
    '''
    This functions takes as arguments the left tables of the texas census text file and the overall file split into sections
    It will then convert the text of muiltiple tables into pandas data frames that then are merged
    The primary key of the table is the texas county
    '''

    pop_sum = left_tables[0:10]
    pop_sum_d = pop_sum[3:10]

    pop_sum_clean_index = []

    for s in pop_sum_d:
        s = s.replace("|", "")
        s = s.replace("Under 18", "Under Eightteen")
        s = s.replace("18 years", "Eighteen years")
        re_s = re.findall("[a-zA-Z ]+", s)
        for string in re_s:
            string = string.rstrip().lstrip()
            pop_sum_clean_index.append(string)

    pop_sum_clean_num = []

    for s in pop_sum_d:
        s = s.replace("|", "")
        s = s.replace("Under 18", "Under Eightteen")
        s = s.replace("18 years", "Eighteen years")
        num = re.findall("[0-9]?[0-9]?[0-9]?\,?[0-9]?[0-9]?[0-9]?\,?\.?[0-9]+", s) 
        for number in num:
            number = number.replace(",","")
            pop_sum_clean_num.append(float(number))
    
    race_sum = left_tables[29:39]
            
    race_sum_clean_index = []

    for s in race_sum:
        s = s.replace("|", "")
        re_s = re.findall("[a-zA-Z\,?\/?\(?\)? ]+", s)
        for string in re_s:
            string = string.rstrip().lstrip()
            if string != ',' and string != '':
                race_sum_clean_index.append(string)
                
    race_sum_clean_num = []

    for s in race_sum:
        s = s.replace("|", "")
        num = re.findall("[0-9]+\,?[0-9]?[0-9]?[0-9]?\,?\.?[0-9]+", s)
        #print(num)
        for number in num[:1]:
            #print(number)
            number = number.replace(",","")
            race_sum_clean_num.append(float(number))

    county = re.findall("[a-zA-Z]+\ ?[a-zA-Z]+ County", splits[0])[0][:-7]
    pop_dict = {"county":pop_sum_clean_index,county:pop_sum_clean_num}
    pop_df = pd.DataFrame(pop_dict)
    pop_df = pop_df.T
    pop_df.columns = pop_df.iloc[0]
    pop_df = pop_df.iloc[1:]
    pop_df = pop_df.reset_index()
    
    race_dict = {"county":race_sum_clean_index,county:race_sum_clean_num}
    race_df = pd.DataFrame(race_dict)
    race_df = race_df.T
    race_df.columns = race_df.iloc[0]
    race_df = race_df.iloc[1:]
    race_df = race_df.reset_index()
    race_df = race_df.rename(columns = {"index":"County"})
    race_df.reset_index(drop=True, inplace=True)

    pop_df.columns = ["County",'Total Population', 'Total Families', 'Total Households',
       'Population in Families', 'Population in Households',
       'Family: Under Eightteen years','House: Under Eightteen years',
       'Family: Eighteen years and over', 'House: Eighteen years and over',
       'Average Family Size', 'Average Household Size',
       'Family: Under Eightteen years', 'House: Under Eightteen years',
       'Family: Eighteen years and over']
    
    race_pop_sum_df = pop_df.merge(race_df, left_on = "County", right_on = "County")

    return race_pop_sum_df

# %%
pathlist = Path("/Users/tsbloxsom/Google Drive/2020 Projects/Census Project").rglob('*.pdf')

appended_data = []

for path in pathlist:
    # because path is object not string
    path_in_str = str(path)
    print(path_in_str)
    
    filename = path_in_str[59:]
    
    text = pdf_to_text(filename)
    #print(text)
    
    left_tables, splits = subset_text_doc(text)
    
    df = get_clean_summary_table(left_tables, splits)
    
    appended_data.append(df)

appended_data = pd.concat(appended_data)
# Out:
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Anderson_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Andrews_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Angelina_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Aransas_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Archer_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Armstrong_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Atascosa_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Austin_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bailey_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bandera_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bastrop_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Baylor_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bee_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bell_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bexar_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Blanco_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Borden_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bosque_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Bowie_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Brazoria_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Brazos_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Brewster_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Briscoe_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Brooks_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Brown_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Burleson_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Burnet_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Caldwell_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Calhoun_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Callahan_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cameron_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Camp_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Carson_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cass_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Castro_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Chambers_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cherokee_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Childress_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Clay_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cochran_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Coke_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Coleman_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Collingsworth_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Collin_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Colorado_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Comal_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Comanche_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Concho_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cooke_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Coryell_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Cottle_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Crane_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Crockett_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Crosby_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Culberson_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Dallam_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Dallas_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Dawson_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Deaf_Smith_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Delta_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Denton_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\De_Witt_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Dickens_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Dimmit_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Donley_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Duval_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Eastland_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Ector_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Edwards_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project\Ellis_2010_SF1_Profile.pdf
# \Users\tsbloxsom\Google Drive\2020 Projects\Census Project
# 0     Yoakum County             7879           2120             2643
# 0      Young County            18550           5223             7343
# 0     Zapata County            14018           3423             4297
# 0     Zavala County            11677           2764             3573
#
#    Population in Families Population in Households  \
# 0                   37417                    44241
# 0                   12922                    14704
# 0                   71618                    83818
# 0                   18281                    22699
# 0                    7786                     8998
# ..                    ...                      ...
# 0                   34315                    40861
# 0                    7112                     7826
# 0                   15436                    18271
# 0                   12729                    13988
# 0                   10067                    11268
#
#    Family: Under Eightteen years House: Under Eightteen years  \
# 0                          11297                        11471
# 0                           4263                         4312
# 0                          22794                        23170
# 0                           4405                         4519
# 0                           2153                         2185
# ..                           ...                          ...
# 0                           8295                         8507
# 0                           2480                         2501
# 0                           4399                         4458
# 0                           4768                         4805
# 0                           3632                         3660
#
#    Family: Eighteen years and over House: Eighteen years and over  ...  \
# 0                            26120                          32770  ...
# 0                             8659                          10392  ...
# 0                            48824                          60648  ...
# 0                            13876                          18180  ...
# 0                             5633                           6813  ...
# ..                             ...                            ...  ...
# 0                            26020                          32354  ...
# 0                             4632                           5325  ...
# 0                            11037                          13813  ...
# 0                             7961                           9183  ...
# 0                             6435                           7608  ...
#
#    Family: Eighteen years and over White alone  \
# 0                             2.15       13660
# 0                             2.18        4315
# 0                             2.18       23686
# 0                             2.12        8826
# 0                             2.17        3376
# ..                             ...         ...
# 0                             2.14       15733
# 0                             2.18        2062
# 0                             2.11        6819
# 0                             2.33        4014
# 0                             2.33        3138
#
#    Black or African American alone American Indian and Alaska Native alone  \
# 0                             2437                                      92
# 0                               76                                      51
# 0                             4624                                     149
# 0                              106                                      80
# 0                               10                                      25
# ..                             ...                                     ...
# 0                              655                                      98
# 0                               30                                      26
# 0                               83                                      54
# 0                               28                                      16
# 0                               16                                      19
#
#    Asian alone Native Hawaiian/Other Pacific Islander alone  \
# 0           68                                           22
# 0           31                                            1
# 0          243                                           15
# 0          154                                            1
# 0           15                                            3
# ..         ...                                          ...
# 0           45                                           15
# 0           12                                            2
# 0           21                                            0
# 0           11                                            0
# 0            2                                           13
#
#    Some Other Race alone Two or More Races Hispanic or Latino (Any race)  \
# 0                    735               220                          1534
# 0                    707                78                          2117
# 0                   2045               338                          4108
# 0                    465               163                          1692
# 0                     83                37                           173
# ..                   ...               ...                           ...
# 0                    419               163                           861
# 0                    457                55                          1280
# 0                    275                91                           818
# 0                    225                23                          3820
# 0                    340                56                          3273
#
#    White alone, not Hispanic
# 0                      12958
# 0                       2973
# 0                      21841
# 0                       7684
# 0                       3295
# ..                       ...
# 0                      15346
# 0                       1299
# 0                       6337
# 0                        448
# 0                        280
#
# [254 rows x 24 columns]

# %%
appended_data.to_csv('5. County Stats.csv', index = False)
